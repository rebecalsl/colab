# %%
#entrada
primeira_letra= input()
segunda_letra= input()
primeiro_simbolo= input()
segundo_simbolo= input()
inteiro= int(input())

#respostas
resposta1 = primeira_letra + primeiro_simbolo
resposta2 = segunda_letra + segundo_simbolo
resposta3 = (resposta1 + resposta2) * inteiro

#saída
print= (resosta1)
print= (resposta2)
print= (resposta3)
# Out:
# vi!
# xe_
# vi!xe_
# vi!xe_1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-42af6eabd160> in <cell line: 6>()
#       4 primeiro_simbolo= input()
#       5 segundo_simbolo= input()
# ----> 6 inteiro= int(input())
#       7
#       8 #respostas
#
# ValueError: invalid literal for int() with base 10: ''
